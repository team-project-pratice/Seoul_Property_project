# %%
import pandas as pd

# %%
data = pd.read_csv('서울시 상권분석서비스(아파트-상권).csv')
data
# Out:
#        기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드          상권_코드_명  아파트_단지_수  \
# 0          20241        A       골목상권  3110008  배화여자대학교(박노수미술관)       145
# 1          20242        A       골목상권  3110008  배화여자대학교(박노수미술관)       145
# 2          20242        A       골목상권  3110009            자하문터널        45
# 3          20242        A       골목상권  3110010            평창동서측        58
# 4          20242        A       골목상권  3110017            정독도서관        10
# ...          ...      ...        ...      ...              ...       ...
# 27964      20204        U       관광특구  3001495          잠실 관광특구        23
# 27965      20203        U       관광특구  3001495          잠실 관광특구        23
# 27966      20202        U       관광특구  3001495          잠실 관광특구        23
# 27967      20201        U       관광특구  3001495          잠실 관광특구        23
# 27968      20194        U       관광특구  3001495          잠실 관광특구        23
#
#        아파트_면적_66_제곱미터_미만_세대_수  아파트_면적_66_제곱미터_세대_수  아파트_면적_99_제곱미터_세대_수  \
# ...

# %%
data[data['기준_년분기_코드'].astype(str).str.contains('2023')]
# Out:
#        기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드          상권_코드_명  아파트_단지_수  \
# 106        20233        A       골목상권  3110020         서울국제고등학교       102
# 271        20231        A       골목상권  3110001           이북5도청사        18
# 297        20231        A       골목상권  3110078         이촌동점보아파트         1
# 328        20234        A       골목상권  3110008  배화여자대학교(박노수미술관)       145
# 502        20233        A       골목상권  3110009            자하문터널        45
# ...          ...      ...        ...      ...              ...       ...
# 23690      20232        D       발달상권  3120125              구로역         4
# 23834      20232        D       발달상권  3120135              양평역         2
# 25560      20232        R       전통시장  3130223           고척근린시장         1
# 25711      20232        R       전통시장  3130138            수유프라자         1
# 27411      20232        R       전통시장  3130104             전곡시장         4
#
#        아파트_면적_66_제곱미터_미만_세대_수  아파트_면적_66_제곱미터_세대_수  아파트_면적_99_제곱미터_세대_수  \
# ...

# %%
data[data['기준_년분기_코드']== ' 20232']
# Out:
# Empty DataFrame
# Columns: [기준_년분기_코드, 상권_구분_코드, 상권_구분_코드_명, 상권_코드, 상권_코드_명, 아파트_단지_수, 아파트_면적_66_제곱미터_미만_세대_수, 아파트_면적_66_제곱미터_세대_수, 아파트_면적_99_제곱미터_세대_수, 아파트_면적_132_제곱미터_세대_수, 아파트_면적_165_제곱미터_세대_수, 아파트_가격_1_억_미만_세대_수, 아파트_가격_1_억_세대_수, 아파트_가격_2_억_세대_수, 아파트_가격_3_억_세대_수, 아파트_가격_4_억_세대_수, 아파트_가격_5_억_세대_수, 아파트_가격_6_억_이상_세대_수, 아파트_평균_면적, 아파트_평균_시가]
# Index: []
