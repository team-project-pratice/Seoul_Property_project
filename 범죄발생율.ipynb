# %%
import pandas as pd

# %%
data = pd.read_csv('5대+범죄+발생현황_20241105152013.csv',encoding='euc-kr')

# %%
data
# Out:
#    자치구별(2)  소계(발생)  소계(검거)  살인(발생)  살인(검거) 강도(발생) 강도(검거)  강간.강제추행(발생)  \
# 0       소계   90399   65097     104      98    117    112         5816
# 1      종로구    3138    3284       2       3      8      8          228
# 2       중구    3071    2119       1       2      5      4          194
# 3      용산구    2967    2093       5       3      7      7          280
# 4      성동구    2194    1597       2       2      2      2          125
# 5      광진구    3619    2498       6       5      -      -          230
# 6     동대문구    3253    2231       4       4      2      2          125
# 7      중랑구    3599    2671       2       2      2      2          150
# 8      성북구    2749    2125       3       3      1      1          158
# 9      강북구    2832    2343       5       4      5      6          177
# 10     도봉구    2141    1569       3       3      -      -           70
# 11     노원구    3896    2641       3       3      3      1          180
# ...

# %%
data_1 = data.drop(data.index[0])

# %%
data_1
data_1['범죄발생 대비 검거율(%)'] = data_1['소계(검거)']/data_1['소계(발생)']
data_1
# Out:
#    자치구별(2)  소계(발생)  소계(검거)  살인(발생)  살인(검거) 강도(발생) 강도(검거)  강간.강제추행(발생)  \
# 1      종로구    3138    3284       2       3      8      8          228
# 2       중구    3071    2119       1       2      5      4          194
# 3      용산구    2967    2093       5       3      7      7          280
# 4      성동구    2194    1597       2       2      2      2          125
# 5      광진구    3619    2498       6       5      -      -          230
# 6     동대문구    3253    2231       4       4      2      2          125
# 7      중랑구    3599    2671       2       2      2      2          150
# 8      성북구    2749    2125       3       3      1      1          158
# 9      강북구    2832    2343       5       4      5      6          177
# 10     도봉구    2141    1569       3       3      -      -           70
# 11     노원구    3896    2641       3       3      3      1          180
# 12     은평구    3487    2658       4       4      5      4          176
# ...

# %%
occurrence = data_1.sort_values(by='소계(발생)',ascending=False)
arrest = data_1.sort_values(by='소계(검거)',ascending=False)
occurrence
# Out:
#    자치구별(2)  소계(발생)  소계(검거)  살인(발생)  살인(검거) 강도(발생) 강도(검거)  강간.강제추행(발생)  \
# 23     강남구    6947    5020      12      10     11     10          667
# 24     송파구    5167    3409       2       2      5      6          290
# 21     관악구    4879    3411      10       8      9      8          327
# 19    영등포구    4819    3186       5       6     10      9          327
# 16     강서구    4663    3591       3       3      7      7          261
# 22     서초구    4459    3098       3       2      3      3          431
# 14     마포구    4096    2814       2       2      2      1          436
# 11     노원구    3896    2641       3       3      3      1          180
# 17     구로구    3857    2732      11      11      8      9          217
# 25     강동구    3711    2644       5       6      5      5          157
# 5      광진구    3619    2498       6       5      -      -          230
# 7      중랑구    3599    2671       2       2      2      2          150
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

plt.figure(figsize=(10, 5))
width = 0.35
xticks = np.arange(len(occurrence['자치구별(2)']))
plt.bar(xticks - width/2, occurrence['소계(발생)'], width, label='범죄 발생 현황')
plt.bar(xticks + width/2, occurrence['소계(검거)'], width, label = '범죄 검거 현황')
plt.rcParams['font.family'] = 'Arial'  # Arial과 같은 한글 지원 폰트로 변경
plt.rcParams['axes.unicode_minus'] = False  # 음수 기호가 깨지는 문제 해결u
plt.rc('font', family='Malgun Gothic')
plt.tight_layout()
plt.xticks(xticks, occurrence['자치구별(2)'], rotation=90)
plt.ylabel('발생건수')
plt.title('범죄발생 현황 및 검거 현황')
plt.legend()
plt.show()

# %%
data_1
data_1['범죄발생 대비 검거율(%)'] = data_1['소계(검거)']/data_1['소계(발생)']
data_2 = data_1.sort_values(by='범죄발생 대비 검거율(%)',ascending=False)
data_2
# Out:
#    자치구별(2)  소계(발생)  소계(검거)  살인(발생)  살인(검거) 강도(발생) 강도(검거)  강간.강제추행(발생)  \
# 1      종로구    3138    3284       2       3      8      8          228
# 9      강북구    2832    2343       5       4      5      6          177
# 8      성북구    2749    2125       3       3      1      1          158
# 16     강서구    4663    3591       3       3      7      7          261
# 12     은평구    3487    2658       4       4      5      4          176
# 7      중랑구    3599    2671       2       2      2      2          150
# 10     도봉구    2141    1569       3       3      -      -           70
# 18     금천구    2577    1887       2       1      3      3          127
# 4      성동구    2194    1597       2       2      2      2          125
# 23     강남구    6947    5020      12      10     11     10          667
# 25     강동구    3711    2644       5       6      5      5          157
# 17     구로구    3857    2732      11      11      8      9          217
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.rcParams['font.family'] = 'Arial'  # Arial과 같은 한글 지원 폰트로 변경
plt.rcParams['axes.unicode_minus'] = False  # 음수 기호가 깨지는 문제 해결u
plt.rc('font', family='Malgun Gothic')
plt.tight_layout()
plt.xticks(rotation=90)
plt.ylabel('%')
plt.title('범죄발생 대비 검거율(%)')
plt.bar(data_2['자치구별(2)'],data_2['범죄발생 대비 검거율(%)'])
# Out:
# <BarContainer object of 25 artists>
