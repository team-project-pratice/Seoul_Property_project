# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
seoul = pd.read_csv("2022사립고등학교.csv")
seoul

# %%
seoul2 = seoul.copy()

# %%
seoul.columns = seoul.iloc[0, :]

# %%
seoul.drop([0, 1, 2], inplace=True)

# %%
seoul.reset_index(drop=True, inplace=True)

# %%
seoul.head(3)
# Out:
# 0 자치구별(2) 학교수 (개) 학급수 (개) 학생수 (명) 학생수 (명) 학생수 (명) 교원수 (명) 교원수 (명) 교원수 (명)  \
# 0      소계     117    3600   86059   43334   42725    7872    3905    3967
# 1     종로구       6     150    2988    1443    1545     356     180     176
# 2      중구       2      46     892     892       -     105      67      38
#
# 0 직원수 (명)  ... 졸업자현황 (명) 졸업자현황 (명) 졸업자현황 (명) 입학자현황 (명) 입학자현황 (명) 입학자현황 (명)  \
# 0     659  ...     31168     15614     15554     29276     28908     14440
# 1      34  ...      1195       611       584      1006       961       451
# 2      10  ...       367       367         -       284       278       278
#
# 0 입학자현황 (명) 교지면적 (천㎡) 건물면적 (천㎡) 교실수 (개)
# 0     14468      2651      1698    5726
# 1       510       118        81     254
# 2         -        37        19      58
#
# [3 rows x 22 columns]

# %%
new_col = ['자치구별(2)','학교수 (개)']
seoul[new_col]
# Out:
# 0  자치구별(2) 학교수 (개)
# 0       소계     117
# 1      종로구       6
# 2       중구       2
# 3      용산구       5
# 4      성동구       -
# 5      광진구       4
# 6     동대문구       4
# 7      중랑구       3
# 8      성북구       6
# 9      강북구       2
# 10     도봉구       1
# 11     노원구      12
# 12     은평구       7
# 13    서대문구       4
# 14     마포구       4
# 15     양천구       8
# 16     강서구      11
# 17     구로구       2
# 18     금천구       2
# 19    영등포구       -
# 20     동작구       3
# 21     관악구       7
# 22     서초구       3
# 23     강남구       9
# 24     송파구       6
# 25     강동구       6

# %%
seoul_sorted = seoul.sort_values(by='학교수 (개)', ascending=False)
seoul_sorted
# Out:
# 0  자치구별(2) 학교수 (개) 학급수 (개) 학생수 (명) 학생수 (명) 학생수 (명) 교원수 (명) 교원수 (명) 교원수 (명)  \
# 23     강남구       9     308    7792    3724    4068     671     326     345
# 15     양천구       8     284    7354    3488    3866     609     298     311
# 12     은평구       7     264    6409    3461    2948     562     249     313
# 21     관악구       7     162    3851    1792    2059     374     187     187
# 25     강동구       6     200    5022    2932    2090     434     216     218
# 24     송파구       6     213    5139    2073    3066     454     235     219
# 8      성북구       6     164    3837    2110    1727     370     188     182
# 1      종로구       6     150    2988    1443    1545     356     180     176
# 3      용산구       5     100    1878     801    1077     229     114     115
# 14     마포구       4     103    2551    1839     712     231     104     127
# 13    서대문구       4     117    2694    1407    1287     253     138     115
# 6     동대문구       4     111    2588     915    1673     247     114     133
# 5      광진구       4     118    2976    1302    1674     259     137     122
# 7      중랑구       3      84    1867     632    1235     180      91      89
# 20     동작구       3      87    2337    1608     729     193     104      89
# 22     서초구       3     117    2880    1115    1765     256     123     133
# 9      강북구       2      76    1898     486    1412     162      69      93
# 17     구로구       2      48    1166     708     458     107      62      45
# 18     금천구       2      64    1431     824     607     143      55      88
# 2       중구       2      46     892     892       -     105      67      38
# 11     노원구      12     421    9904    4807    5097     898     435     463
# 0       소계     117    3600   86059   43334   42725    7872    3905    3967
# 16     강서구      11     330    7908    4975    2933     704     389     315
# 10     도봉구       1      33     697       -     697      75      24      51
# 19    영등포구       -       -       -       -       -       -       -       -
# 4      성동구       -       -       -       -       -       -       -       -
#
# 0  직원수 (명)  ... 졸업자현황 (명) 졸업자현황 (명) 졸업자현황 (명) 입학자현황 (명) 입학자현황 (명) 입학자현황 (명)  \
# 23      50  ...      2729      1318      1411      2625      2625      1228
# 15      44  ...      2610      1197      1413      2488      2474      1157
# 12      40  ...      2279      1190      1089      2184      2164      1181
# 21      40  ...      1356       635       721      1370      1346       627
# 25      34  ...      1715      1007       708      1724      1719      1010
# 24      36  ...      1906       778      1128      1671      1648       652
# 8       35  ...      1469       803       666      1317      1304       694
# 1       34  ...      1195       611       584      1006       961       451
# 3       25  ...       735       305       430       616       604       244
# 14      16  ...       922       685       237       896       894       652
# 13      22  ...      1015       573       442       926       900       437
# 6       22  ...       950       300       650       873       872       302
# 5       26  ...      1068       485       583      1046      1027       436
# 7       18  ...       662       215       447       711       666       233
# 20      18  ...       765       505       260       784       783       539
# 22      19  ...      1010       388       622      1014      1001       385
# 9       12  ...       696       179       517       636       642       167
# 17      11  ...       389       232       157       441       432       247
# 18      12  ...       458       274       184       513       506       297
# 2       10  ...       367       367         -       284       278       278
# 11      66  ...      3688      1791      1897      3216      3176      1567
# 0      659  ...     31168     15614     15554     29276     28908     14440
# 16      63  ...      2923      1776      1147      2692      2643      1656
# 10       6  ...       261         -       261       243       243         -
# 19       -  ...         -         -         -         -         -         -
# 4        -  ...         -         -         -         -         -         -
#
# 0  입학자현황 (명) 교지면적 (천㎡) 건물면적 (천㎡) 교실수 (개)
# 23      1397       262       162     483
# 15      1317       116       101     392
# 12       983       177       107     379
# 21       719       227        88     283
# 25       709       113        75     302
# 24       996       161       117     357
# 8        610       130        90     252
# 1        510       118        81     254
# 3        360       100        61     196
# 14       242        96        45     176
# 13       463        69        61     199
# 6        570        81        67     218
# 5        591        78        46     192
# 7        433        65        48     157
# 20       244       142        53     145
# 22       616        99        51     175
# 9        475        25        30     114
# 17       185        60        29      79
# 18       209        78        34      90
# 2          -        37        19      58
# 11      1609       224       171     638
# 0      14468      2651      1698    5726
# 16       987       167       148     520
# 10       243        28        16      67
# 19         -         -         -       -
# 4          -         -         -       -
#
# [26 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


fm._rebuild()


plt.rc('font', family='Malgun Gothic')  # Windows


plt.boxplot([12, 15, 14, 10, 18, 25, 30, 33, 22])
plt.title('한글이 깨지지 않도록 설정')

plt.show()

# %%
plt.plot(seoul_sorted['자치구별(2)'],seoul_sorted['학교수 (개)'])
plt.rc('font',family = 'Malgun Gothic')
plt.xticks(rotation=90)
plt.title('서울 각 자치구별 학교 수')
plt.xlabel('학교수 (개)')
plt.ylabel('자치구별(2)')
plt.show()
